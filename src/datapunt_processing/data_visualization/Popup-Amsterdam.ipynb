# %%
import os
import folium
import json
import branca.colormap as cm
import pandas as pd
import requests
import numpy as np
import random
import re

# %%
index = [i for i in range(20)]
test_df = pd.DataFrame(index=index)
test_df["Name"] = [''.join([random.choice("abcdefghijklmnopqrstuvwxyz") for _ in range(10)]) for i in range(20)]
test_df["lon"] = np.random.uniform(4.72876, 5.07916, test_df.shape[0])
test_df["lat"] = np.random.uniform(52.269470, 52.4322, test_df.shape[0])
test_df["Value"] =  np.random.randint(0, 100, test_df.shape[0])
test_df
# Out:
#           Name       lon        lat  Value
# 0   qniktragxd  4.733018  52.376934     30
# 1   ahuwqmsnlj  4.972137  52.334866      4
# 2   gkskiwobqo  4.968087  52.351241     85
# 3   pveharhwho  4.987313  52.314868     27
# 4   lhkikonqao  4.922578  52.365981      9
# 5   mcnptvdhyr  4.772127  52.376553     12
# 6   lklsehpkak  4.873306  52.289379     42
# 7   escacyuokn  4.892714  52.272226     78
# 8   vtsnrnddob  5.062256  52.369250     85
# 9   ogjvvjsaxn  5.030758  52.383848     91
# 10  vhlkazuhda  4.898188  52.418368     51
# 11  tmmkdvnmxh  4.913993  52.316147      2
# 12  foenxrfiky  4.999769  52.297817     25
# 13  yshxceinfz  4.860340  52.319988     87
# 14  zcnazhwdym  4.884356  52.396051     15
# 15  iczlmtxrnl  4.889512  52.324543     93
# 16  optmijogci  4.826229  52.396083     50
# 17  hnyeirqkfx  5.058901  52.327058     56
# 18  qnpgbomxvl  4.771374  52.401396      9
# 19  hmoenvaqmq  5.060102  52.417532     47

# %%
def create_popup_map(df, output_name):
    """
    Input: 
        - df, contains at least:
            - Name (string with name of datapoint)
            - Value (value for this datapoint) 
            - lon 
            - lat

        - output_name (string): how do you want te file to be saved
    Ouput: html with data on map
    
    """
        
    if bool(re.search(r"\W", output_name)):
        print("ongeldige outputnaam, outputnaam mag alleen letters, cijfers of _ bevatten")
        return
    
    if not "Name" in df.columns or not "Value" in df.columns or not "lon" in df.columns or not "lat" in df.columns:
        print("dataframe moet 'Name','Value', 'lon' en 'lat' bevatten")
        return

    m = folium.Map(location=[52.379189, 4.899431], tiles='https://{s}.data.amsterdam.nl/topo_google/{z}/{x}/{y}.png',    
                    attr='Amsterdam', zoom_start=13, min_lat=52.269470,
                   max_lat=52.4322, min_lon=4.72876, max_lon=5.07916, subdomains=['t1', 't2', 't3', 't4'])

    for index, row in df.iterrows():  
        if row['lon']== 0:
            pass
        else:
            html = u"<b> Naam: </b> {} <br> <b> Waarde: </b> {} <br>".format(row['Name'], row['Value'])  
            html = re.sub(r"'", '&#39;', html) #recplace ' with &#39 to prevent error (ASCII code)
            folium.Marker([row['lat'], row['lon']], popup = html).add_to(m)

    m.save('{}.html'.format(output_name))
    print('Popup map is succesfully saved as:' + output_name)
    return m

# %%
create_popup_map(test_df, 'popuptest')
# Out:
# Popup map is succesfully saved as:popuptest
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
